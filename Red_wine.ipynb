# %% [markdown]
# # Data Processing
# >The first stage of the data analysis is to process my data. I began by checking null values and duplicates and got rid of them to enable me work with a clean data. I used the pandas library in python for my data analysis.

# %%
import pandas as pd

# %%
dta = pd.read_csv('data.csv')

# %%
dta
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
dta.shape
# Checking the number of rows and columns in the dataset
# Out:
# (1601, 13)

# %% [markdown]
# # Dealing with the null values
# >After looping through the dataset, I realised that some of the columns contained null values. The approach I used to handle the null values is to find the mean of the particular column which has a null value and fill the empty space with the mean calculated. The reason I used this approach instead of removing the null values is that I wanted my data intact, thus every data accounted for. After handling the null values, I checked for duplicates and removed them.

# %%
dta.info()
# Obtaining information about the columns and rows of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1600 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1600 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1598 non-null   float64
#  6   free sulfur dioxide   1600 non-null   float64
#  7   total sulfur dioxide  1600 non-null   float64
#  8   density               1600 non-null   float64
#  9   pH                    1600 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1600 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
dta.isnull().sum()
# Checking the number of null values in each column.
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %%
# Finding the mean of the individual columns
mean_FA = dta['fixed acidity'].mean()
mean_VA = dta['volatile acidity'].mean()
mean_CA = dta['citric acid'].mean()
mean_RS = dta['residual sugar'].mean()
mean_C = dta['chlorides'].mean()
mean_FSD = dta['free sulfur dioxide'].mean()
mean_TSD = dta['total sulfur dioxide'].mean()
mean_D = dta['density'].mean()
mean_PH = dta['pH'].mean()
mean_S = dta['sulphates'].mean()
mean_A = dta['alcohol'].mean()
mean_Q = dta['quality'].mean()

# %%
# Printing out the mean of the columns with some including the null values

print(f'The mean of fixed acidity including null = {mean_FA}')
print(f'The mean of volatile acidity = {mean_VA}')
print(f'The mean of citric acid including null = {mean_CA}')
print(f'The mean of residual sugar = {mean_RS}')
print(f'The mean of chlorides including null = {mean_C}')
print(f'The mean of free sulfur dioxide including null = {mean_FSD}')
print(f'The mean of total sulfur dioxide including null = {mean_TSD}')
print(f'The mean of density including null = {mean_D}')
print(f'The mean of pH including null = {mean_PH}')
print(f'The mean of sulphates = {mean_S}')
print(f'The mean of alcohol = {mean_A}')
print(f'The mean of quality including null = {mean_FA}')
# Out:
# The mean of fixed acidity including null = 8.319875000000001
# The mean of volatile acidity = 0.5277420362273579
# The mean of citric acid including null = 0.271175
# The mean of residual sugar = 2.5384447220487196
# The mean of chlorides including null = 0.0874874843554443
# The mean of free sulfur dioxide including null = 15.886875
# The mean of total sulfur dioxide including null = 46.52
# The mean of density including null = 0.9967456437500002
# The mean of pH including null = 3.3111062500000004
# The mean of sulphates = 0.6582198625858838
# The mean of alcohol = 10.42320424734541
# The mean of quality including null = 8.319875000000001

# %%
# Replacing the columns which have the null values with their appropraite mean

dta['fixed acidity'] = dta['fixed acidity'].fillna(mean_FA)
dta['citric acid'] = dta['citric acid'].fillna(mean_CA)
dta['chlorides'] = dta['chlorides'].fillna(mean_C)
dta['total sulfur dioxide'] = dta['total sulfur dioxide'].fillna(mean_TSD)
dta['density'] = dta['density'].fillna(mean_D)
dta['pH'] = dta['pH'].fillna(mean_PH)
dta['quality'] = dta['quality'].fillna(mean_Q)
dta['free sulfur dioxide'] = dta['free sulfur dioxide'].fillna(mean_FSD)

# %%
# Replacing the columns which have the null values with their appropraite mean

dta['fixed acidity'] = dta['fixed acidity'].fillna(mean_FA)
dta['citric acid'] = dta['citric acid'].fillna(mean_CA)
dta['chlorides'] = dta['chlorides'].fillna(mean_C)
dta['total sulfur dioxide'] = dta['total sulfur dioxide'].fillna(mean_TSD)
dta['density'] = dta['density'].fillna(mean_D)
dta['pH'] = dta['pH'].fillna(mean_PH)
dta['quality'] = dta['quality'].fillna(mean_Q)
dta['free sulfur dioxide'] = dta['free sulfur dioxide'].fillna(mean_FSD)

# %%
dta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
dta.drop_duplicates()
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density        pH  \
# ...

# %% [markdown]
# # Statistical Inferences Of Entire Dataset
# >After preprocessing the data, I performed statistical inferences on the entire data. I used the 'describe' method in pandas to get the statistical inferences on the data, thus mean, standard deviation, count, minimum value, maximum value, 25th percentile, 50th percentile(Median), 75th perrcentile and maximum value for each column.

# %%
dta.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# # Statistical Inferences On Individual Columns
# >I moved on to use the describe method to calculate the staistical inferences of the individual colmns

# %%
dta['fixed acidity'].describe()
# Out:
# count    1601.000000
# mean        8.319875
# std         1.739495
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
dta['volatile acidity'].describe()
# Out:
# count    1601.000000
# mean        0.527742
# std         0.178981
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
dta['citric acid'].describe()
# Out:
# count    1601.000000
# mean        0.271175
# std         0.194684
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.420000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
dta['residual sugar'].describe()
# Out:
# count    1601.000000
# mean        2.538445
# std         1.409138
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
dta['chlorides'].describe()
# Out:
# count    1601.000000
# mean        0.087487
# std         0.047032
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090000
# max         0.611000
# Name: chlorides, dtype: float64

# %%
dta['free sulfur dioxide'].describe()
# Out:
# count    1601.000000
# mean       15.886875
# std        10.455218
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
dta['total sulfur dioxide'].describe()
# Out:
# count    1601.000000
# mean       46.520000
# std        32.967416
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        62.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
dta['density'].describe()
# Out:
# count    1601.000000
# mean        0.996746
# std         0.001887
# min         0.990070
# 25%         0.995600
# 50%         0.996750
# 75%         0.997830
# max         1.003690
# Name: density, dtype: float64

# %%
dta['pH'].describe()
# Out:
# count    1601.000000
# mean        3.311106
# std         0.154290
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
dta['sulphates'].describe()
# Out:
# count    1601.000000
# mean        0.658220
# std         0.169471
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
dta['alcohol'].describe()
# Out:
# count    1601.000000
# mean       10.423204
# std         1.065495
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
dta['quality'].describe()
# Out:
# count    1601.000000
# mean        5.636250
# std         0.807116
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %% [markdown]
# # Hidden Inferences
# >In addition to the statistical inferences, I also looked for some hidden inferences in the dataset. Example I used the 'corr()' method to check for the correlation between the different columns in the dataset.

# %%
dta.corr()
# Out:
#                             ID  fixed acidity  volatile acidity  citric acid  \
# ID                    1.000000      -0.267899         -0.009544    -0.153294
# fixed acidity        -0.267899       1.000000         -0.255557     0.670856
# volatile acidity     -0.009544      -0.255557          1.000000    -0.552909
# citric acid          -0.153294       0.670856         -0.552909     1.000000
# residual sugar       -0.031589       0.114595          0.001877     0.143517
# chlorides            -0.119131       0.093472          0.060748     0.203981
# free sulfur dioxide   0.091145      -0.152932         -0.010591    -0.061252
# total sulfur dioxide -0.113809      -0.113325          0.076247     0.036014
# density              -0.368725       0.667693          0.022753     0.364104
# pH                    0.135082      -0.682452          0.235182    -0.542637
# sulphates            -0.124243       0.182291         -0.261364     0.312839
# ...

# %% [markdown]
# # Visualization Of Data
# >I used heatmaps and barchat to visualize the correlation between different columns in the dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes = True)

plt.figure(figsize=(10,8))
sns.heatmap(dta.corr(), annot = True, cmap = 'coolwarm')
plt.title('Correlation between different colomns in the dataset')
plt.show()

# %%
sns.barplot(dta.corr())
# Out:
# <AxesSubplot: >

# %%
sns.displot(dta['quality'])

# %%
sns.pairplot(dta[['fixed acidity','chlorides','density', 'alcohol']])
